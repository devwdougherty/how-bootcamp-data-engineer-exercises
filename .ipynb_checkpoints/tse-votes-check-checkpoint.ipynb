# %%
pip install requests bs4 pandas

# %%
pip install lxml html5lib

# %%
pip install urllib3
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import urllib3

# %%
url = "https://resultados.tse.jus.br/oficial/app/index.html#/eleicao;zn=0028;se={}/dados-de-urna;e=e545;uf=mt;ufbu=mt;mubu=90280/boletim-de-urna"

# %%
ret = requests.get(url.format('0102'))

# %%
ret = requests.get('https://resultados.tse.jus.br/oficial/ele2022/arquivo-urna/407/dados/mt/90280/0028/0102/796730456a576562426d514c5a5156452b787462346a6f4a4b427474515a365663302d78765a6f506d4a4d3d/o00407-9028000280102.imgbu')

# %%
ret
# Out:
# <Response [200]>

# %%
http = urllib3.PoolManager()
url = 'https://resultados.tse.jus.br/oficial/ele2022/arquivo-urna/407/dados/mt/90280/0028/0102/796730456a576562426d514c5a5156452b787462346a6f4a4b427474515a365663302d78765a6f506d4a4d3d/o00407-9028000280102.imgbu'
response = http.request('GET', url)
data = response.data
data_ok = data.split("\n")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [16], line 5
#       3 response = http.request('GET', url)
#       4 data = response.data
# ----> 5 data_ok = data.split("\n")
#
# TypeError: a bytes-like object is required, not 'str'

# %%
response.data
for line in response.data: # files are iterable
    print(line)
# Out:
# 48
# 130
# 10
# 82
# 48
# 21
# 27
# 15
# 50
# 48
# 50
# 50
# 49
# 48
# 51
# 48
# 84
# 49
# 54
# 48
# 53
# 49
# 51
# 130
# 2
# 1
# 151
# 10
# 1
# 2
# 48
# 113
# 10
# 1
# 1
# 27
# 23
# 56
# 46
# 50
# 54
# 46
# 48
# 46
# 48
# 32
# 45
# 32
# 79
# 110
# 231
# 97
# 45
# 112
# 105
# 110
# 116
# 97
# 100
# 97
# 48
# 74
# 160
# 16
# 48
# 8
# 2
# 3
# 1
# 96
# 168
# 2
# 1
# 28
# 2
# 1
# 1
# 2
# 1
# 102
# 48
# 54
# 2
# 3
# 16
# 98
# 226
# 4
# 4
# 4
# 2
# 49
# 206
# 27
# 15
# 50
# 48
# 50
# 50
# 48
# 57
# 50
# 50
# 84
# 48
# 55
# 52
# 51
# 48
# 48
# 27
# 24
# 48
# 52
# 48
# 53
# 48
# 54
# 51
# 53
# 55
# 50
# 53
# 52
# 51
# 53
# 49
# 54
# 55
# 55
# 54
# 50
# 48
# 53
# 48
# 50
# 10
# 1
# 1
# 4
# 4
# 123
# 251
# 250
# 204
# 160
# 17
# 48
# 8
# 2
# 3
# 1
# 96
# 168
# 2
# 1
# 28
# 2
# 2
# 4
# 131
# 2
# 1
# 102
# 10
# 1
# 4
# 4
# 130
# 9
# 171
# 21
# 19
# 32
# 74
# 117
# 115
# 116
# 105
# 231
# 97
# 32
# 69
# 108
# 101
# 105
# 116
# 111
# 114
# 97
# 108
# 10
# 21
# 32
# 32
# 32
# 84
# 114
# 105
# 98
# ...

# %%
soup = bs(ret.text, 'html.parser')

# %%
soup.text.split('\n')
# Out:
# ['0�',
#  'R0\x15\x1b\x0f20221030T160513�\x02\x01�',
#  '\x01\x020q',
#  '\x01\x01\x1b\x178.26.0.0 - On�a-pintada0J�\x100\x08\x02\x03\x01`�\x02\x01\x1c\x02\x01\x01\x02\x01f06\x02\x03\x10b�\x04\x04\x04\x021�\x1b\x0f20220922T074300\x1b\x18040506357254351677620502',
#  '\x01\x01\x04\x04{��̠\x110\x08\x02\x03\x01`�\x02\x01\x1c\x02\x02\x04�\x02\x01f',
#  '\x01\x04\x04�\t�\x15\x13 Justi�a Eleitoral',
#  '\x15   Tribunal Regional Eleitoral [MT]',
#  '',
#  '           Boletim de Urna',
#  '',
#  '         Elei��es Gerais 2022',
#  '               2� Turno',
#  '             (30/10/2022)',
#  '',
#  'Munic�pio                        90280',
#  '               CONFRESA',
#  '',
#  'Zona Eleitoral                    0028',
#  'Local de Vota��o                  1155',
#  'Se��o Eleitoral                   0102',
#  '',
#  'Eleitores aptos                   0394',
#  'Comparecimento                    0285',
#  'Eleitores faltosos                0109',
#  '',
# ...

# %%
soup.find_parent('PRESIDENTE')
